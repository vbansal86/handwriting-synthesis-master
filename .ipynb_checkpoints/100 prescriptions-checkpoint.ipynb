# %%
import numpy as np
import pandas as pd

# %%
Dlist =     ['Diazepam' , 'Zopiclone'  , 'Olanzapine'  , 'Quetiapine' , 'Lofepramine' , 'Escitalopram' ,'Dosulepin HCl' , 'Venlafaxine cap' , 'Priadel' , 'Buspirone' ]

# %%
df = pd.read_csv('drug.csv')

# %%
n = len(df)

# %%
pattern = '|'.join(Dlist)

# %%
col =   df['BNF NAME                                    '].str[:40]

# %%
df1  = col.str.contains(pattern)

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
df2 = df[df1]

# %%
df2['Drug Name'] = df2['BNF NAME                                    '].str[:40]
# Out:
# C:\Users\vbdon\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.drop(df2.columns[[8]], axis=1, inplace=True)
# Out:
# C:\Users\vbdon\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#    Unnamed: 0  Seq PRACTICE first_name    last_name                   Address  \
# 0           0  1.0   Y04937      Bobbi  Philippeaux  21549 Summer Ridge Trail
# 1           1  2.0   Y04937      Bobbi  Philippeaux  21549 Summer Ridge Trail
# 2           2  3.0   Y04937      Bobbi  Philippeaux  21549 Summer Ridge Trail
# 3           3  4.0   Y04937      Bobbi  Philippeaux  21549 Summer Ridge Trail
# 5           5  6.0   Y04937      Bobbi  Philippeaux  21549 Summer Ridge Trail
#
#    Styles  Biases                                 Drug Name
# 0      11     0.0  Zopiclone_Tab 7.5mg
# 1      11     0.0  Diazepam_Tab 2mg
# 2      11     0.0  Quetiapine_Tab 25mg
# 3      11     0.0  Quetiapine_Tab 200mg M/R
# 5      11     0.0  Olanzapine_Tab 15mg

# %%
df2.sort_values(['Drug Name','PRACTICE'],ascending=[True,True],inplace=True)
# Out:
# C:\Users\vbdon\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#         Unnamed: 0       Seq PRACTICE first_name last_name  \
# 206132      206132  205958.0   A81004   Karlotta   Fiander
# 206930      206930  206756.0   A81005        Van   Blaxton
# 186207      186207  186054.0   A81011     Johnny    Briant
# 208395      208395  208220.0   A81012     Lianne    Oiseau
# 187718      187718  187563.0   A81017    Patrice   Huggens
#
#                      Address  Styles  Biases  \
# 206132    572 Eastlawn Point       1     2.0
# 206930  9 Bellgrove Crossing       7     1.4
# 186207      91 Melrose Point       4     1.4
# 208395        66 Hudson Park      10     0.8
# 187718       60 Cherokee Way      11     1.6
#
#                                        Drug Name
# 206132  Buspirone HCl_Tab 10mg
# 206930  Buspirone HCl_Tab 10mg
# 186207  Buspirone HCl_Tab 10mg
# 208395  Buspirone HCl_Tab 10mg
# 187718  Buspirone HCl_Tab 10mg

# %%
df2.head(n=40)
# Out:
#         Unnamed: 0       Seq PRACTICE first_name        last_name  \
# 206132      206132  205958.0   A81004   Karlotta          Fiander
# 206930      206930  206756.0   A81005        Van          Blaxton
# 186207      186207  186054.0   A81011     Johnny           Briant
# 208395      208395  208220.0   A81012     Lianne           Oiseau
# 187718      187718  187563.0   A81017    Patrice          Huggens
# 211915      211915  211736.0   A81019   Silvanus       Avramovich
# 215387      215387  215206.0   A81023        Ted        Fawthorpe
# 190213      190213  190055.0   A81031     Almeta            Marke
# 192249      192249  192091.0   A81036    Melania  Oldfield-Cherry
# 220950      220950  220767.0   A81037     Irvine        Grishagin
# 194678      194678  194517.0   A81041   Patricia           Searle
# 223893      223893  223709.0   A81045      Peria        Trowsdale
# 196430      196430  196268.0   A81046   Panchito             Copp
# ...

# %%
df2.to_csv("drug_100.csv")
